# %%
# %sql
create schema charan_schema

# %%
# %sql
create table charan_schema.charan_table
(
  id int,
  salary int
) using delta location "dbfs:/FileStore/rawdata/deltatables"

# %%
# %sql
insert into charan_schema.charan_table values (4,32000),(5, 52000),(6, 75000)

# %% [markdown]
# #### OPTIMIZE

# %%
# %sql
optimize delta.`/FileStore/rawdata/deltatables` zorder by(id)
