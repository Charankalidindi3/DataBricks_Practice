# %% [markdown]
# #### Turning OFF AQE and DPP and AutoBroadcast

# %%
spark.conf.set("spark.sql.adaptove.enabled","true")
spark.conf.set("spark.sql.optimizer.dynamicPartitionPruning.enabled","true")
spark.conf.set("spark.sql.autoBroadcastJoinThreshold",5 * 1024 *  1024)

# %%
df= spark.read.format("csv")\
    .option("header","true")\
    .option("inferSchema","true")\
    .load("/FileStore/rawdata/BigMart_Sales.csv")
df=df.limit(10)

# %%
df.display()

# %% [markdown]
# #### Preparing the Partitioned Data

# %%
df.write.format("parquet")\
        .mode("append")\
        .partitionBy("Item_Identifier")\
        .option("path","/FileStore/rawdata/dpp_partitionednew/")\
        .save()

# %% [markdown]
# #### Non-Partitioned Data

# %%
df.write.format("parquet")\
        .mode("append")\
        .option("path","/FileStore/rawdata/dpp_partitioned/")\
        .save()

# %% [markdown]
# #### Dataframes

# %%
df1 =spark.read.format("parquet")\
        .load("/FileStore/rawdata/dpp_partitionednew/")

# %%
df2 = spark.read.format("parquet")\
        .load("/FileStore/rawdata/dpp_partitioned/")

# %%
from pyspark.sql.functions import *

# %% [markdown]
# #### JOINS

# %%
df_join = df1.join(df2.filter(col("Item_Identifier")== "FDA15"), df1['Item_Identifier'] == df2['Item_Identifier'],"inner")

# %%
df_join.display()
